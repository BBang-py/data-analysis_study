# %% [markdown]
# # 수면 데이터 불러오기 및 기본 구조 탐색

# %%
import pandas as pd

# %%
#csv 데이터 읽기

df = pd.read_csv(
    "Sleep_health_and_lifestyle_dataset.csv",
)

# %%
#데이터넷 구조보기

df.shape
# Out:
# (374, 13)

# %% [markdown]
# 데이터셋의 구조는 행 374개 , 컬럼 13개

# %%
#Feauture의 데이터 타입 보기

df.dtypes
# Out:
# Person ID                    int64
# Gender                         str
# Age                          int64
# Occupation                     str
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                   str
# Blood Pressure                 str
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder                 str
# dtype: object

# %%
#고객ID int -> str 데이터 타입 바꾸기

df= df.astype({"Person ID" : "object"})

# %%
df.dtypes
# Out:
# Person ID                   object
# Gender                         str
# Age                          int64
# Occupation                     str
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                   str
# Blood Pressure                 str
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder                 str
# dtype: object

# %%
# Person ID	개인 식별 번호
# Gender	성별
# Age	나이
# Occupation	직업
# Sleep Duration	수면 시간
# Quality of Sleep	수면의 질 점수
# Physical Activity Level	신체 활동 수준
# Stress Level	스트레스 수준
# BMI Category	체질량지수(BMI) 범주
# Blood Pressure	혈압
# Heart Rate	심박수
# Daily Steps	하루 걸음 수
# Sleep Disorder	수면장애 유형

# %%
#데이터 샘플 보기(맨 앞 10개)

df.head(10)
# Out:
#   Person ID Gender  Age            Occupation  Sleep Duration  \
# 0         1   Male   27     Software Engineer             6.1
# 1         2   Male   28                Doctor             6.2
# 2         3   Male   28                Doctor             6.2
# 3         4   Male   28  Sales Representative             5.9
# 4         5   Male   28  Sales Representative             5.9
# 5         6   Male   28     Software Engineer             5.9
# 6         7   Male   29               Teacher             6.3
# 7         8   Male   29                Doctor             7.8
# 8         9   Male   29                Doctor             7.8
# 9        10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
#데이터 샘플 보기(맨 뒤 10개)

df.tail(10)
# Out:
#     Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 364       365  Female   59      Nurse             8.0                 9
# 365       366  Female   59      Nurse             8.0                 9
# 366       367  Female   59      Nurse             8.1                 9
# 367       368  Female   59      Nurse             8.0                 9
# 368       369  Female   59      Nurse             8.1                 9
# 369       370  Female   59      Nurse             8.1                 9
# 370       371  Female   59      Nurse             8.0                 9
# 371       372  Female   59      Nurse             8.1                 9
# 372       373  Female   59      Nurse             8.1                 9
# 373       374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 364                       75             3   Overweight         140/95
# ...

# %%
#결측치 개수 확인

df.isna().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
#한 컬럼에 어떤 값들이 있는지 확인

print(f"수면장애 유형: \n{df["Sleep Disorder"].unique()}\n")

print(f"직업: \n{df["Occupation"].unique()}")
# Out:
# 수면장애 유형:
# <StringArray>
# [nan, 'Sleep Apnea', 'Insomnia']
# Length: 3, dtype: str
#
# 직업:
# <StringArray>
# [   'Software Engineer',               'Doctor', 'Sales Representative',
#               'Teacher',                'Nurse',             'Engineer',
#            'Accountant',            'Scientist',               'Lawyer',
#           'Salesperson',              'Manager']
# Length: 11, dtype: str

# %%
#csv의 수면장애 유형 : "None"은 결측치가 아닌 수면장애가 없다는 뜻 그래서 "None" 이 결측치로 입력되지 않게 해야 함

df = pd.read_csv(
    "Sleep_health_and_lifestyle_dataset.csv",
    keep_default_na=False
)

# %%
df.isna().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
df["Sleep Disorder"].unique()
# Out:
# <StringArray>
# ['None', 'Sleep Apnea', 'Insomnia']
# Length: 3, dtype: str

# %% [markdown]
# # 데이터 선택

# %%
#인덱스가 3~10 행 데이터 뽑기

df.loc[3:10 , :]
# Out:
#     Person ID Gender  Age            Occupation  Sleep Duration  \
# 3           4   Male   28  Sales Representative             5.9
# 4           5   Male   28  Sales Representative             5.9
# 5           6   Male   28     Software Engineer             5.9
# 6           7   Male   29               Teacher             6.3
# 7           8   Male   29                Doctor             7.8
# 8           9   Male   29                Doctor             7.8
# 9          10   Male   29                Doctor             7.8
# 10         11   Male   29                Doctor             6.1
#
#     Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                  4                       30             8        Obese
# 4                  4                       30             8        Obese
# 5                  4                       30             8        Obese
# 6                  6                       40             7        Obese
# ...

# %%
#인덱스가 25~35 행 데이터 나이, 직업, 수면시간 뽑기

df.loc[25:35,["Age","Occupation", "Sleep Duration"]]
# Out:
#     Age Occupation  Sleep Duration
# 25   30     Doctor             7.9
# 26   30     Doctor             7.8
# 27   30     Doctor             7.9
# 28   30     Doctor             7.9
# 29   30     Doctor             7.9
# 30   30      Nurse             6.4
# 31   30      Nurse             6.4
# 32   31      Nurse             7.9
# 33   31     Doctor             6.1
# 34   31     Doctor             7.7
# 35   31     Doctor             6.1

# %%
#3행 5열 데이터 뽑기(5열은 Quality of Sleep)

df.iloc[3,5]
# Out:
# np.int64(4)

# %%
#3~7행 5~6열 데이터 뽑기//*loc의 n:k 는 n부터 k까지(k포함), iloc의 n:k 는 n부터 k-1까지(k미포함)

df.iloc[3:8,5:7]
# Out:
#    Quality of Sleep  Physical Activity Level
# 3                 4                       30
# 4                 4                       30
# 5                 4                       30
# 6                 6                       40
# 7                 7                       75

# %% [markdown]
# # 조건 필터링

# %%
#수면 시간이 6시간 이상인 행 데이터 뽑기

df[df["Quality of Sleep"] >= 6]
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 1            2    Male   28             Doctor             6.2
# 2            3    Male   28             Doctor             6.2
# 6            7    Male   29            Teacher             6.3
# 7            8    Male   29             Doctor             7.8
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# 373        374  Female   59              Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#직업이 의사인 행 데이터 뽑기

df[df["Occupation"] == "Doctor"]
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 1            2    Male   28     Doctor             6.2                 6
# 2            3    Male   28     Doctor             6.2                 6
# 7            8    Male   29     Doctor             7.8                 7
# 8            9    Male   29     Doctor             7.8                 7
# 9           10    Male   29     Doctor             7.8                 7
# ..         ...     ...  ...        ...             ...               ...
# 266        267    Male   48     Doctor             7.3                 7
# 276        277    Male   49     Doctor             8.1                 9
# 277        278    Male   49     Doctor             8.1                 9
# 341        342  Female   56     Doctor             8.2                 9
# 342        343  Female   56     Doctor             8.2                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %%
# 성별이 남자이면서 스트레스 레벨이 5 이상인 사람

df[(df["Gender"] == "Male") & (df["Stress Level"] >= 5)]
# Out:
#      Person ID Gender  Age            Occupation  Sleep Duration  \
# 0            1   Male   27     Software Engineer             6.1
# 1            2   Male   28                Doctor             6.2
# 2            3   Male   28                Doctor             6.2
# 3            4   Male   28  Sales Representative             5.9
# 4            5   Male   28  Sales Representative             5.9
# ..         ...    ...  ...                   ...             ...
# 247        248   Male   44              Engineer             6.8
# 248        249   Male   44           Salesperson             6.4
# 249        250   Male   44           Salesperson             6.5
# 264        265   Male   48                Doctor             7.3
# 266        267   Male   48                Doctor             7.3
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#직업이 의사거나 간호사인 사람중에서 수면시간이 7시간 미만인 사람
#isin(): 컬럼안에 ()안에 있는 값이 있으면 True

df[(df["Occupation"].isin(["Doctor", "Nurse"])) & (df["Sleep Duration"] < 7)]
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 1            2    Male   28     Doctor             6.2                 6
# 2            3    Male   28     Doctor             6.2                 6
# 10          11    Male   29     Doctor             6.1                 6
# 12          13    Male   29     Doctor             6.1                 6
# 13          14    Male   29     Doctor             6.0                 6
# ..         ...     ...  ...        ...             ...               ...
# 296        297  Female   50      Nurse             6.1                 6
# 297        298  Female   50      Nurse             6.1                 6
# 303        304  Female   51      Nurse             6.0                 6
# 304        305  Female   51      Nurse             6.1                 6
# 305        306  Female   51      Nurse             6.1                 6
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
#나이가 40이상 50이하인 사람
#between(a,b) : a이상 b이하

df[df["Age"].between(40,50)]
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 161        162  Female   40  Accountant             7.2                 8
# 162        163  Female   40  Accountant             7.2                 8
# 163        164    Male   40      Lawyer             7.9                 8
# 164        165    Male   40      Lawyer             7.9                 8
# 165        166    Male   41      Lawyer             7.6                 8
# ..         ...     ...  ...         ...             ...               ...
# 293        294  Female   50       Nurse             6.0                 6
# 294        295  Female   50       Nurse             6.1                 6
# 295        296  Female   50       Nurse             6.0                 6
# 296        297  Female   50       Nurse             6.1                 6
# 297        298  Female   50       Nurse             6.1                 6
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %% [markdown]
# # 데이터 정렬

# %%
# 수면 시간이 오름차순으로 정렬

df.sort_values("Sleep Duration")
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 81          82  Female   34             Scientist             5.8
# 80          81  Female   34             Scientist             5.8
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# 5            6    Male   28     Software Engineer             5.9
# ..         ...     ...  ...                   ...             ...
# 330        331  Female   53              Engineer             8.5
# 327        328  Female   53              Engineer             8.5
# 299        300  Female   51              Engineer             8.5
# 298        299  Female   51              Engineer             8.5
# 301        302  Female   51              Engineer             8.5
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 81                  4                       32             8   Overweight
# ...

# %%
# 육제 활동 레벨을 오름차순으로 정렬

df.sort_values("Physical Activity Level",ascending=True)
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 17          18    Male   29     Doctor             6.0                 6
# 321        322  Female   53   Engineer             8.4                 9
# 338        339  Female   54   Engineer             8.5                 9
# 337        338  Female   54   Engineer             8.4                 9
# 325        326  Female   53   Engineer             8.5                 9
# ..         ...     ...  ...        ...             ...               ...
# 296        297  Female   50      Nurse             6.1                 6
# 293        294  Female   50      Nurse             6.0                 6
# 295        296  Female   50      Nurse             6.0                 6
# 341        342  Female   56     Doctor             8.2                 9
# 342        343  Female   56     Doctor             8.2                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %%
#나이를 기준으로 오름차순 , 나이가 같을 시 스트레스 레벨을 기준으로 내림차순

df.sort_values(by= ["Age","Stress Level"],ascending=[True,False])
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# # 그룹별 집계

# %% [markdown]
# ## 집계함수

# %% [markdown]
# | 함수               | 의미                        |
# | ---------------- | ------------------------- |
# | `mean()`         | 평균                        |
# | `median()`       | 중앙값                       |
# | `sum()`          | 합계                        |
# | `min()`          | 최솟값                       |
# | `max()`          | 최댓값                       |
# | `count()`        | **결측값을 제외한** 값의 개수        |
# | `size()`         | **결측값 포함** 그룹의 행 개수       |
# | `std()`          | 표준편차 — 값이 얼마나 퍼져 있는지      |
# | `var()`          | 분산 — 표준편차의 제곱             |
# | `nunique()`      | 서로 다른 값의 개수, 기본적으로 결측값 제외 |
# | `quantile(0.25)` | 25% 분위수                   |

# %%
#직업별 사람 수/* 추가로 오름차순으로 정렬

df.groupby("Occupation").size().sort_values(ascending=True)
# Out:
# Occupation
# Manager                  1
# Sales Representative     2
# Software Engineer        4
# Scientist                4
# Salesperson             32
# Accountant              37
# Teacher                 40
# Lawyer                  47
# Engineer                63
# Doctor                  71
# Nurse                   73
# dtype: int64

# %%
#직업별 나이 평균 /* 추가로 round()로 반올림하고 오름차순으로 정렬

df.groupby("Occupation")["Age"].mean().round(1).sort_values(ascending=True)
# Out:
# Occupation
# Sales Representative    28.0
# Software Engineer       31.2
# Doctor                  32.7
# Scientist               33.5
# Lawyer                  39.4
# Accountant              39.6
# Teacher                 41.7
# Salesperson             43.5
# Manager                 45.0
# Engineer                46.6
# Nurse                   51.8
# Name: Age, dtype: float64

# %%
#BMI 범주별 스트레스 레벨과 수면 시간의 평균

df.groupby("BMI Category")[["Stress Level","Sleep Duration"]].mean().round(2)
# Out:
#                Stress Level  Sleep Duration
# BMI Category
# Normal                 5.13            7.39
# Normal Weight          5.19            7.33
# Obese                  5.70            6.96
# Overweight             5.73            6.77

# %%
#집계 함수를 한번에 쓰려면 agg사용
#직업별 하루 걸음수의 평균과 최댓값 

df.groupby("Occupation")["Daily Steps"].agg(["mean" , "max"]).round(1).sort_values("mean" , ascending=False)
# Out:
#                         mean    max
# Occupation
# Nurse                 8057.5  10000
# Lawyer                7661.7   8000
# Accountant            6881.1   7500
# Doctor                6808.5  10000
# Salesperson           6000.0   6000
# Engineer              5981.0   8000
# Teacher               5957.5   7000
# Software Engineer     5800.0   8000
# Manager               5500.0   5500
# Scientist             5350.0   5500
# Sales Representative  3000.0   3000

# %% [markdown]
# # 데이터 시각화

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar chart

# %%
#우선 직업별 걸음수의 평균을 가져옴 
mean_steps = df.groupby("Occupation")["Daily Steps"].mean().astype("int64").sort_values()
mean_steps
# Out:
# Occupation
# Sales Representative    3000
# Scientist               5350
# Manager                 5500
# Software Engineer       5800
# Teacher                 5957
# Engineer                5980
# Salesperson             6000
# Doctor                  6808
# Accountant              6881
# Lawyer                  7661
# Nurse                   8057
# Name: Daily Steps, dtype: int64

# %%
#가로 10인치, 세로 6인치 크기의 그림 생성
plt.Figure(figsize=(10,6))

# %%
#막대 그래프 생성
plt.bar(mean_steps.index,mean_steps.values)
# Out:
# <BarContainer object of 11 artists>

# %%
#위의 그래프의 직업 글자가 겹쳐 세로 막대그래프로 변경
plt.barh(mean_steps.index,mean_steps.values)
# Out:
# <BarContainer object of 11 artists>

# %%
#축 이름 설점 /* rotation= :글자 회전
#grid(): 점선 격자 추가 /* axis =: 축방향 , linestyle =: 선모양 , alpha=: 투명도

plt.xlabel("Average Daily Steps",)
plt.ylabel("Occupation",rotation=0)
plt.grid(axis="x", linestyle="-", alpha=0.3)
plt.barh(mean_steps.index,mean_steps.values)
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(df["Sleep Duration"],df["Stress Level"],alpha=0.3)
plt.xlabel("Sleep Duration")
plt.ylabel("Stress Level",rotation=0)
plt.show()

# %%
#ylabel이 그래프를 넘어와서 조정해야함
#labelpad= : 축과 제목 사이 간격 늘리기
#plt.tight_layout(): 여백 자동 조절

plt.scatter(df["Sleep Duration"], df["Stress Level"], alpha=0.3)

plt.xlabel("Sleep Duration")
plt.ylabel("Stress Level", rotation=0,labelpad=40)
plt.tight_layout()
plt.show()
